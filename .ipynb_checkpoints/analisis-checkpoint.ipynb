# %% [markdown]
# # Análisis de un archivo CSV sobre votaciones electorales en el estado de Queretaro

# %% [markdown]
# ## Equipo 3
# * Briones Tapia Sarahí
# * Larrazolo Barrera Bruno
# * López Guerrero Arcadio

# %% [markdown]
# Importamos las librerías necesarias

# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Función para obtener los distintos distritos

# %%
def limpiar_distritos(df,distrito):
    dist=df.loc[df['DISTRITO_LOCAL']==distrito]
    dist=dist["TOTAL_VOTOS_SACADOS"]
    dist=dist.tolist()
    dist_num=[]
    for i in dist:
        try:
            dist_num.append(int(i))
        except:
            pass

    total_dist=sum(dist_num)
    return total_dist

# %% [markdown]
# Función para contabilizar los votos de un tipo de casilla

# %%
def votos_casilla(df,distrito,tipo):
    dist=df.loc[(df['DISTRITO_LOCAL']==distrito) & (df['TIPO_CASILLA']==tipo)]
    dist=dist["TOTAL_PERSONAS_VOTARON"]
    dist=dist.tolist()
    dist_num=[]
    for i in dist:
        try:
            dist_num.append(int(i))
        except:
            pass

    total_dist=sum(dist_num)
    return total_dist

# %% [markdown]
# Función para contabilizar los votos nulos registrados

# %%
def votos_nulos(df,distrito):
    dist=df.loc[df['DISTRITO_LOCAL']==distrito]
    dist=dist["NULOS"]
    dist=dist.tolist()
    dist_num=[]
    for i in dist:
        try:
            dist_num.append(int(i))
        except:
            pass

    total_dist=sum(dist_num)
    return total_dist

# %% [markdown]
# Función para contabilizar los votos registrados

# %%
def participacion_por_distrito(df,distrito):
    dist=df.loc[df['DISTRITO_LOCAL']==distrito]
    dist=dist["TOTAL_PERSONAS_VOTARON"]
    dist=dist.tolist()
    dist_num=[]
    for i in dist:
        try:
            dist_num.append(int(i))
        except:
            pass

    total_dist=sum(dist_num)
    return total_dist

# %% [markdown]
# Función para contabilizar los votos esperados en cada distrito según la lista nominal

# %%
def esperados_por_distrito(df,distrito):
    dist=df.loc[df['DISTRITO_LOCAL']==distrito]
    dist=dist["LISTA_NOMINAL"]
    dist=dist.tolist()
    dist_num=[]
    for i in dist:
        try:
            dist_num.append(int(i))
        except:
            pass

    total_dist=sum(dist_num)
    return total_dist

# %% [markdown]
# Función para contabilizar el total de votos asentados en cada distrito

# %%
def ejercidos_por_distrito(df,distrito):
    dist=df.loc[df['DISTRITO_LOCAL']==distrito]
    dist=dist["TOTAL_VOTOS_ASENTADO"]
    dist=dist.tolist()
    dist_num=[]
    for i in dist:
        try:
            dist_num.append(int(i))
        except:
            pass

    total_dist=sum(dist_num)
    return total_dist

# %% [markdown]
# Función para contabilizar los votos sacados de la urna registrados en una casilla

# %%
def votos_urna_por_distrito(df,distrito):
    dist=df.loc[df['DISTRITO_LOCAL']==distrito]
    dist=dist["TOTAL_VOTOS_SACADOS"]
    dist=dist.tolist()
    dist_num=[]
    for i in dist:
        try:
            dist_num.append(int(i))
        except:
            pass

    total_dist=sum(dist_num)
    return total_dist

# %% [markdown]
# Funcion para obtener los distintos distritos

# %%
def obten_distritos_unicos(distritos):
    unicos = []

    for distrito in distritos:
        if distrito in unicos:
            continue
        else:
            unicos.append(distrito)
    return unicos

distritos=df[df.columns[5]]
distritos=list(distritos)

# %% [markdown]
# Limpieza del CSV base

# %%
#______________Limpieza del archivo base_______________________________
datos=pd.read_csv('QRO_DIP_LOC_2018.csv', skiprows=5)
columna_clave_acta= datos['CLAVE_ACTA']
columna_clave_casilla= datos['CLAVE_CASILLA']

#Limpieza de la columna CLAVE_ACTA
for i in range(len(columna_clave_acta)):
    if str(datos.loc[i, 'CLAVE_ACTA']).find("E"):
        datos.loc[i, 'CLAVE_ACTA']=str(datos.loc[i, 'CLAVE_ACTA'])[1:]
    else:
        datos.loc[i, 'CLAVE_ACTA'] = str(datos.loc[i, 'CLAVE_ACTA'].replace("'",""))
    
#Limpieza de la columna CLAVE_CASILLA
for j in range(len(columna_clave_casilla)):
    if str(datos.loc[j, 'CLAVE_CASILLA']).find("E"):
        datos.loc[j, 'CLAVE_CASILLA']=str(datos.loc[j, 'CLAVE_CASILLA'])[1:]
    else:
        datos.loc[j, 'CLAVE_CASILLA'] = str(datos.loc[j, 'CLAVE_CASILLA'].replace("'",""))

#Guardamos el nuevo archivo
datos.to_csv('archivo_modificado.csv', index=False)

# %% [markdown]
# ## Visualizaciones importantes sobre los datos que se encontraron en el CSV

# %%
df=pd.read_csv('QRO_DIP_LOC_2018.csv', skiprows=5)
df.head()
# Out:
#   CLAVE_CASILLA   CLAVE_ACTA  ID_ESTADO     ESTADO  ID_DISTRITO_LOCAL  \
# 0   220277B0100  220277B0100         22  QUERETARO                  1
# 1   220277C0100  220277C0100         22  QUERETARO                  1
# 2   220277C0200  220277C0200         22  QUERETARO                  1
# 3   220277C0300  220277C0300         22  QUERETARO                  1
# 4   220277C0400  220277C0400         22  QUERETARO                  1
#
#   DISTRITO_LOCAL  SECCION  ID_CASILLA TIPO_CASILLA  EXT_CONTIGUA  ...  \
# 0   QUERETARO 01      277         961            B             0  ...
# 1   QUERETARO 01      277         962            C             0  ...
# 2   QUERETARO 01      277         963            C             0  ...
# 3   QUERETARO 01      277         964            C             0  ...
# 4   QUERETARO 01      277         965            C             0  ...
#
#   OBSERVACIONES  CONTABILIZADA MECANISMOS_TRASLADO  \
# 0           NaN            1.0                   D
# 1           NaN            1.0                   D
# 2           NaN            1.0                   D
# 3           NaN            1.0                   D
# 4           NaN            1.0                   D
#
#                                                  SHA    FECHA_HORA_ACOPIO  \
# 0  77B4E74C39AA83026388F7148239AF76816E8B6D29CC03...  02/07/2018 01:18:43
# 1  C055A6A27C574F57BE0185476BC19756D0290CB26C9FB6...  02/07/2018 01:17:20
# 2  83A57141BC2CB59F7A4D43069AF9DBBA5B13B61320FC59...  02/07/2018 00:42:16
# 3  AB96359CA2A806F9B8A96D9666FC3D74571BA564F32DA1...  02/07/2018 01:18:11
# 4  4D527753D1E7D940AEA1CE9FF61E66A3237D5255359759...  02/07/2018 00:42:51
#
#     FECHA_HORA_CAPTURA FECHA_HORA_VERIFICACION ORIGEN DIGITALIZACION  \
# 0  02/07/2018 02:18:53     02/07/2018 04:25:39   CATD        ESCANER
# 1  02/07/2018 04:40:41     02/07/2018 05:41:19   CATD        ESCANER
# 2  02/07/2018 01:03:58     02/07/2018 01:15:12   CATD        ESCANER
# 3  02/07/2018 02:40:52     02/07/2018 05:05:53   CATD        ESCANER
# 4  02/07/2018 01:09:11     02/07/2018 01:37:26   CATD        ESCANER
#
#   TIPO_DOCUMENTO
# 0      ACTA PREP
# 1      ACTA PREP
# 2      ACTA PREP
# 3      ACTA PREP
# 4      ACTA PREP
#
# [5 rows x 83 columns]

# %% [markdown]
# Visualizaremos de manera general el tipo de datos que contiene:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2648 entries, 0 to 2647
# Data columns (total 83 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   CLAVE_CASILLA                 2648 non-null   object
#  1   CLAVE_ACTA                    2648 non-null   object
#  2   ID_ESTADO                     2648 non-null   int64
#  3   ESTADO                        2648 non-null   object
#  4   ID_DISTRITO_LOCAL             2648 non-null   int64
#  5   DISTRITO_LOCAL                2648 non-null   object
#  6   SECCION                       2648 non-null   int64
#  7   ID_CASILLA                    2648 non-null   int64
#  8   TIPO_CASILLA                  2648 non-null   object
#  9   EXT_CONTIGUA                  2648 non-null   int64
#  10  UBICACION_CASILLA             2648 non-null   object
#  11  TIPO_ACTA                     2648 non-null   int64
#  12  TOTAL_BOLETAS_SOBRANTES       2475 non-null   object
#  13  TOTAL_PERSONAS_VOTARON        2475 non-null   object
#  14  TOTAL_REP_PARTIDO_CI_VOTARON  2475 non-null   object
#  15  TOTAL_VOTOS_SACADOS           2475 non-null   object
#  16  PAN                           2475 non-null   object
#  17  PRI                           2475 non-null   object
#  18  PRD                           2475 non-null   object
#  19  MC                            2331 non-null   object
#  20  PANAL                         2475 non-null   object
#  21  PVEM                          2475 non-null   object
#  22  PES                           2475 non-null   object
#  23  M                             2475 non-null   object
#  24  PT                            2475 non-null   object
#  25  CQ                            2475 non-null   object
#  26  QI                            2475 non-null   object
#  27  MORENA_PT_PES                 2300 non-null   object
#  28  MORENA_PT                     2300 non-null   object
#  29  MORENA_PES                    2300 non-null   object
#  30  PT_PES                        2300 non-null   object
#  31  PRI_PVEM                      1983 non-null   object
#  32  PAN_PRD_MC                    331 non-null    object
#  33  PAN_PRD                       1518 non-null   object
#  34  PAN_MC                        331 non-null    object
#  35  PRD_MC                        331 non-null    object
#  36  CAND_IND_1                    2648 non-null   object
#  37  CAND_IND_2                    162 non-null    object
#  38  CAND_IND_3                    2648 non-null   object
#  39  CAND_IND_4                    2648 non-null   object
#  40  CAND_IND_5                    2648 non-null   object
#  41  CAND_IND_6                    2648 non-null   object
#  42  CAND_IND_7                    2648 non-null   object
#  43  CAND_IND_8                    2648 non-null   object
#  44  CAND_IND_9                    2648 non-null   object
#  45  CAND_IND_10                   172 non-null    object
#  46  CAND_IND_11                   2648 non-null   object
#  47  CAND_IND_12                   2648 non-null   object
#  48  CAND_IND_13                   2648 non-null   object
#  49  CAND_IND_14                   161 non-null    object
#  50  CAND_IND_15                   144 non-null    object
#  51  CAND_IND_16                   2648 non-null   object
#  52  CAND_IND_17                   2648 non-null   object
#  53  CAND_IND_18                   2648 non-null   object
#  54  CAND_IND_19                   2648 non-null   object
#  55  CAND_IND_20                   2648 non-null   object
#  56  CAND_IND_21                   2648 non-null   object
#  57  CAND_IND_22                   2648 non-null   object
#  58  CAND_IND_23                   174 non-null    object
#  59  CAND_IND_24                   177 non-null    object
#  60  CAND_IND_25                   167 non-null    object
#  61  CAND_IND_26                   2648 non-null   object
#  62  CAND_IND_27                   2648 non-null   object
#  63  CAND_IND_28                   2648 non-null   object
#  64  CAND_IND_29                   2648 non-null   object
#  65  CAND_IND_30                   2648 non-null   object
#  66  CAND_IND_31                   2648 non-null   object
#  67  NO_REGISTRADOS                2475 non-null   object
#  68  NULOS                         2475 non-null   object
#  69  TOTAL_VOTOS_ASENTADO          2475 non-null   object
#  70  TOTAL_VOTOS_CALCULADO         2475 non-null   float64
#  71  LISTA_NOMINAL                 2648 non-null   int64
#  72  REPRESENTANTES_PP_CI          2648 non-null   int64
#  73  OBSERVACIONES                 580 non-null    object
#  74  CONTABILIZADA                 2476 non-null   float64
#  75  MECANISMOS_TRASLADO           2648 non-null   object
#  76  SHA                           2475 non-null   object
#  77  FECHA_HORA_ACOPIO             2648 non-null   object
#  78  FECHA_HORA_CAPTURA            2475 non-null   object
#  79  FECHA_HORA_VERIFICACION       2436 non-null   object
#  80  ORIGEN                        2648 non-null   object
#  81  DIGITALIZACION                2648 non-null   object
#  82  TIPO_DOCUMENTO                2475 non-null   object
# dtypes: float64(2), int64(8), object(73)
# memory usage: 1.7+ MB

# %% [markdown]
# # 01 - Consulta para obtener cuantas casillas hay en cada distrito del estado de Queretaro

# %%
cantidad_de_casillas_p_estado = df["DISTRITO_LOCAL"].value_counts()


plt.style.use('seaborn-whitegrid')

fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(cantidad_de_casillas_p_estado.index, cantidad_de_casillas_p_estado, color='#6495ED')


for i, v in enumerate(cantidad_de_casillas_p_estado):
    ax.text(i, v + 20, str(v), color='black', ha='center', fontsize=8)


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('none')
ax.xaxis.tick_bottom()
ax.set_axisbelow(True)
ax.grid(False, axis='y')


plt.title('Cantidad de Casillas por Distrito', fontsize=14, fontweight='bold')
plt.xlabel('Distrito', fontsize=10)
plt.ylabel('Cantidad de Casillas', fontsize=10)
plt.xticks(rotation=45, ha='right', fontsize=8)
plt.yticks(fontsize=8)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Bruno Barrera\AppData\Local\Temp\ipykernel_29612\1358350894.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # 02 - Consulta para obtener cuantos tipos de casillas distintas hay

# %%
cantidad_tipos_de_casillas = df["TIPO_CASILLA"].value_counts()


plt.style.use('seaborn-pastel')

fig, ax = plt.subplots(figsize=(8, 8))
sizes = cantidad_tipos_de_casillas.values
labels = cantidad_tipos_de_casillas.index
colors = ['#6495ED', '#FFA07A', '#90EE90', '#FFD700']


wedges, text_autopct, text_label = ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors, textprops={'fontsize': 12})


ax.axis('equal')


for wedge, label, autopct_text in zip(wedges, labels, text_autopct):
    percentage = autopct_text.get_text()
    tipo_casilla_count = sizes[list(labels).index(label)]
    wedge.set_edgecolor('white')  
    wedge.set_linewidth(1.5) 
    label_text = f'{label}: {tipo_casilla_count} casillas'
    autopct_text.set_text(f'{percentage}\n{label_text}') 


plt.title('Distribución de Tipos de Casillas', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Bruno Barrera\AppData\Local\Temp\ipykernel_29612\4081917598.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-pastel')

# %% [markdown]
# # 03 - Consulta para obtener y graficar la cantidad de casillas con ubicaciones "urbanas" y "no urbanas"

# %%
casillas_urbana = df.query('UBICACION_CASILLA == "URBANA"')
casillas_no_urbana = df.query('UBICACION_CASILLA != "URBANA"')


plt.style.use('seaborn-pastel')

fig, ax = plt.subplots(figsize=(6, 6))
sizes = [len(casillas_urbana), len(casillas_no_urbana)]
labels = ['Urbano', 'No urbano']
colors = ['#6495ED', '#FFA07A']


wedges, text_autopct, text_label = ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, colors=colors, textprops={'fontsize': 12})


ax.axis('equal')


for wedge, label, autopct_text in zip(wedges, labels, text_autopct):
    percentage = autopct_text.get_text()
    casilla_count = sizes[labels.index(label)]
    wedge.set_edgecolor('white')  
    wedge.set_linewidth(1.5)  
    label_text = f'{label}: {casilla_count} casillas'
    autopct_text.set_text(f'{percentage}\n{label_text}')  

# Añadir título
plt.title('Distribución de Casillas por Ubicación', fontsize=14, fontweight='bold')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 04 - Consulta para obtener la cantidad de los distintos tipos de actas

# %%
cantidad_tipos_de_actas=df["TIPO_ACTA"].value_counts()
plt.bar(cantidad_tipos_de_actas.index,cantidad_tipos_de_actas)
plt.rc('ytick', labelsize=15)
plt.rc('xtick', labelsize=10)
plt.title('Tipos de actas registradas', fontsize=15, fontweight='bold')
plt.show()

# %% [markdown]
# * Obtenemos una lista de los distritos que conforman los registros del CSV

# %%
distritos_distintos=df["DISTRITO_LOCAL"].unique().tolist()

# %% [markdown]
# # 05 - Consulta para obtener la cantidad de votos obtenidos por distrito

# %%
lista_totales=[]
for i in distritos_distintos:
    lista_totales.append(limpiar_distritos(df,i))
    

fig,ax = plt.subplots()
ax.barh(distritos_distintos,lista_totales)
plt.rc('ytick', labelsize=15)
plt.rc('xtick', labelsize=20)
plt.title('Votos obtenidos por distritos', fontsize=15, fontweight='bold')
plt.show()

# %% [markdown]
# # 06 - Consulta para analizar el Total de Votos que fueron capturados en casillas contiguas

# %%
casilla_basica="C"
total_votos_casillas_contiguas=[]
for i in distritos_distintos:
    total_votos_casillas_contiguas.append(votos_casilla(df,i,casilla_basica))



fig,ax = plt.subplots()
ax.barh(distritos_distintos,total_votos_casillas_contiguas)
plt.title('Total de personas que votaron en casilla Contigua por distrito', fontsize=15, fontweight='bold')
plt.xlabel('Total personas que votaron en casillas Contigua')
plt.ylabel('Distrito')
plt.rc('ytick', labelsize=10)
plt.rc('xtick', labelsize= 7)
plt.rc('font', size=10)
plt.rc('axes', titlesize=20)
plt.show()

# %% [markdown]
# # 07 - Consulta para analizar el Total de Votos que fueron capturados en casillas especiales

# %%
casilla_especial = "S"
total_votos_casillas_especiales = []
for i in distritos_distintos:
    total_votos_casillas_especiales.append(votos_casilla(df, i, casilla_especial))

# Configuración de estilo
plt.style.use('seaborn-whitegrid')

fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(distritos_distintos, total_votos_casillas_especiales, color='#6495ED')

# Etiquetas de datos en las barras
for i, v in enumerate(total_votos_casillas_especiales):
    ax.text(v + 3, i, str(v), color='black', fontsize=8, va='center')

# Estilización de la gráfica
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('none')
ax.xaxis.tick_bottom()
ax.set_axisbelow(True)
ax.grid(False, axis='y')

# Añadir título y etiquetas
plt.title('Total de personas que votaron en casilla especial por distrito', fontsize=14, fontweight='bold')
plt.xlabel('Total personas que votaron en casillas especiales', fontsize=10)
plt.ylabel('Distrito', fontsize=10)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 08 - Consulta para analizar los Votos Nulos por distrito

# %%
total_votos_nulos = []
for i in distritos_distintos:
    total_votos_nulos.append(votos_nulos(df, i))

plt.style.use('seaborn-whitegrid')

fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(distritos_distintos, total_votos_nulos, color='#6495ED')

for i, v in enumerate(total_votos_nulos):
    ax.text(v + 3, i, str(v), color='black', fontsize=8, va='center')

# Estilización de la gráfica
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('none')
ax.xaxis.tick_bottom()
ax.set_axisbelow(True)
ax.grid(False, axis='y')

# Añadir título y etiquetas
plt.title('Total de votos nulos por distrito', fontsize=14, fontweight='bold')
plt.xlabel('Total votos nulos', fontsize=10)
plt.ylabel('Distrito', fontsize=10)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 09 - Consulta para analizar la participación ciudadana por distrito

# %%
total_participacion = []
for i in distritos_distintos:
    total_participacion.append(participacion_por_distrito(df, i))


plt.style.use('seaborn-whitegrid')

fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(distritos_distintos, total_participacion, color='#6495ED')


for i, v in enumerate(total_participacion):
    ax.text(v + 3, i, str(v), color='black', fontsize=8, va='center')

# Estilización de la gráfica
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('none')
ax.xaxis.tick_bottom()
ax.set_axisbelow(True)
ax.grid(False, axis='y')

# Añadir título y etiquetas
plt.title('Participación ciudadana en cada distrito', fontsize=14, fontweight='bold')
plt.xlabel('Total participantes', fontsize=10)
plt.ylabel('Distrito', fontsize=10)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 10 - Consulta para analizar los votantes que no asistieron, de acuerdo a la lista nominal y el total de votos asentados por cada distrito

# %%
total_votos_esperados = []
for i in distritos_distintos:
    total_votos_esperados.append(esperados_por_distrito(df, i))

total_votos_ejercidos = []
for j in distritos_distintos:
    total_votos_ejercidos.append(ejercidos_por_distrito(df, j))

faltante_votos = [abs(total_votos_esperados[s] - total_votos_ejercidos[s]) for s in range(len(total_votos_esperados))]

plt.style.use('seaborn-whitegrid')

fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(distritos_distintos, faltante_votos, color='#6495ED')

for i, v in enumerate(faltante_votos):
    ax.text(v + 3, i, str(v), color='black', fontsize=8, va='center')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('none')
ax.xaxis.tick_bottom()
ax.set_axisbelow(True)
ax.grid(False, axis='y')


plt.title('Votantes faltantes con respecto a los votantes esperados en cada distrito', fontsize=14, fontweight='bold')
plt.xlabel('Votos de más', fontsize=10)
plt.ylabel('Distrito', fontsize=10)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Bruno Barrera\AppData\Local\Temp\ipykernel_29612\971915825.py:11: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # 11 - En esta consulta obtendremos el total de votos en las elecciones

# %%
import numpy as np
import matplotlib.pyplot as plt

partidos = df[df.columns[16:67]]
partidos_list = []

for i in range(len(list(partidos))):
    votos_partido = list(partidos[partidos.columns[i]])
    r = []
    
    for j in votos_partido:
        try:
            r.append(int(j))
        except:
            pass
    
    partidos_list.append(r)

totales = [sum(l) for l in partidos_list]
nombres_partidos = partidos.columns.values


plt.style.use('seaborn-whitegrid')


colores = ['#6495ED', '#FFA07A', '#7B68EE', '#FFD700', '#90EE90', '#9370DB', '#FF69B4', '#00BFFF']

fig, ax = plt.subplots(figsize=(8, 6))
ax.barh(nombres_partidos, totales, color=colores)


for i, v in enumerate(totales):
    ax.text(v + 3, i, str(v), color='black', fontsize=8, va='center')

# Estilización de la gráfica
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('none')
ax.xaxis.tick_bottom()
ax.set_axisbelow(True)
ax.grid(False, axis='y')


plt.title('Votos por partido', fontsize=14, fontweight='bold')
plt.xlabel('Total de votos', fontsize=10)
plt.ylabel('Partidos', fontsize=10)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Bruno Barrera\AppData\Local\Temp\ipykernel_29612\487214515.py:23: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # 12 - Total de votos por partido y por distrito

# %%
import numpy as np
import matplotlib.pyplot as plt

nombres_distritos = obten_distritos_unicos(distritos)

# ESTILO
plt.style.use('seaborn-whitegrid')

# Colores
colores = ['#6495ED', '#FFA07A', '#7B68EE', '#FFD700', '#90EE90', '#9370DB', '#FF69B4', '#00BFFF']

for d in nombres_distritos:
    registros_p_distrito = df.query('DISTRITO_LOCAL == @d')
    partidos = registros_p_distrito[registros_p_distrito.columns[16:67]]
    partidos_list = []
    
    for i in range(len(list(partidos))):
        votos_partido = list(partidos[partidos.columns[i]])
        r = []
        
        for j in votos_partido:
            try:
                r.append(int(j))
            except:
                pass
        
        partidos_list.append(r)

    totales = [sum(l) for l in partidos_list]
    nombres_part = partidos.columns.values
    
    fig, ax = plt.subplots(figsize=(8, 6))
    ax.barh(nombres_part, totales, color=colores)
    ax.invert_yaxis()
    
    for i, v in enumerate(totales):
        ax.text(v + 3, i, str(v), color='black', fontsize=8, va='center')
    
    # ESTILO
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('none')
    ax.xaxis.tick_bottom()
    ax.set_axisbelow(True)
    ax.grid(False, axis='y')
    
    # Atítulo y etiquetas
    plt.title('Votos por partido en el distrito ' + d, fontsize=14, fontweight='bold')
    plt.xlabel('Total de votos', fontsize=10)
    plt.ylabel('Partidos', fontsize=10)
    plt.xticks(fontsize=8)
    plt.yticks(fontsize=8)
    
    # colores
    legend_labels = ['Partido ' + str(i+1) for i in range(len(colores))]
    ax.legend(legend_labels, loc='lower right', fontsize=8)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## La misma consulta en grafica de pastel

# %%
import numpy as np
import matplotlib.pyplot as plt

nombres_distritos = obten_distritos_unicos(distritos)

# Configuración de estilo
plt.style.use('seaborn-whitegrid')

# Colores personalizados para las partes del pastel
colores = ['#6495ED', '#FFA07A', '#7B68EE', '#FFD700', '#90EE90', '#9370DB', '#FF69B4', '#00BFFF']

for d in nombres_distritos:
    registros_p_distrito = df.query('DISTRITO_LOCAL == @d')
    partidos = registros_p_distrito[registros_p_distrito.columns[16:67]]
    partidos_list = []
    
    for i in range(len(list(partidos))):
        votos_partido = list(partidos[partidos.columns[i]])
        r = []
        
        for j in votos_partido:
            try:
                r.append(int(j))
            except:
                pass
        
        partidos_list.append(r)

    totales = [sum(l) for l in partidos_list]
    nombres_part = partidos.columns.values
    
    fig, ax = plt.subplots(figsize=(6, 6))
    ax.pie(totales, labels=nombres_part, colors=colores, autopct='%1.1f%%', startangle=90)
    
    # Estilización de la gráfica
    ax.axis('equal')
    
    # Añadir título
    plt.title('Distribución de votos por partido en el distrito ' + d, fontsize=14, fontweight='bold')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# Votantes por
